# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Датасет_импорт.xlsx')
df.head(3)
# Out:
#     Год  Импорт России важнейших товаров, млн долл США  \
# 0  2011                                       222845.7
# 1  2012                                       240534.0
# 2  2013                                       236397.7
#
#    Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  \
# 0                                           0.021476
# 1                                           0.037035
# 2                                           0.158609
#
#    Коэфициент прироста производства по основным импортозамещающим продуктам животноводства  \
# 0                                           0.038445
# 1                                           0.058505
# 2                                           0.051147
#
#    Оборот средних организаций по субъектам РФ, млрд. руб.  \
# 0                                             3925.6
# 1                                             4136.1
# 2                                             4295.9
#
# ...

# %%
df28_40 = pd.read_excel('Датасет_импорт_28-40.xlsx')
df50_67 = pd.read_excel('Датасет_импорт_50-67.xlsx')
df72_83 = pd.read_excel('Датасет_импорт_72-83.xlsx')

# %% [markdown]
# ## 1. Анализ признаков: типы данных, пропуски, количество данных, медиана, максимум, минимум, стандартное отклонение

# %% [markdown]
# ### Датасет: Импорт России важнейших товаров, млн долл США

# %%
df.dtypes
# Out:
# Год                                                                                           int64
# Импорт России важнейших товаров, млн долл США                                               float64
# Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам    float64
# Коэфициент прироста производства по основным импортозамещающим продуктам животноводства     float64
# Доля импорта отдельных товаров в их товарных ресурсах, %                                    float64
# Оборот средних организаций по субъектам РФ, млрд. руб.                                      float64
# Удельный вес потребительских товаров в общем объеме импорта РФ, %                           float64
# Индекс промышленного производства, в%                                                       float64
# dtype: object

# %%
df.shape
# Out:
# (11, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Год                                                                                       11 non-null     int64
#  1   Импорт России важнейших товаров, млн долл США                                             11 non-null     float64
#  2   Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  11 non-null     float64
#  3   Коэфициент прироста производства по основным импортозамещающим продуктам животноводства   11 non-null     float64
#  4   Доля импорта отдельных товаров в их товарных ресурсах, %                                  11 non-null     float64
# ...

# %%
df.describe()
# Out:
#                Год  Импорт России важнейших товаров, млн долл США  \
# count    11.000000                                      11.000000
# mean   2016.000000                                   11642.911189
# std       3.316625                                    3413.892300
# min    2011.000000                                    4662.130769
# 25%    2013.500000                                    9794.523077
# 50%    2016.000000                                   11211.107692
# 75%    2018.500000                                   14117.796154
# max    2021.000000                                   15562.984615
#
#        Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  \
# count                                          11.000000
# mean                                            0.069159
# std                                             0.043734
# min                                             0.012779
# ...

# %% [markdown]
# ### Датасет: Импорт продукции химической промышленности, каучука, млн. долл. США

# %%
df28_40.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Год                                                                                       11 non-null     int64
#  1   28-40 Импорт продукции химической промышленности, каучука, млн. долл. США                 11 non-null     float64
#  2   Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  11 non-null     float64
#  3   Коэфициент прироста производства по основным импортозамещающим продуктам животноводства   11 non-null     float64
#  4   Доля импорта отдельных товаров в их товарных ресурсах, %                                  11 non-null     float64
# ...

# %%
df28_40.dtypes
# Out:
# Год                                                                                           int64
# 28-40 Импорт продукции химической промышленности, каучука, млн. долл. США                   float64
# Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам    float64
# Коэфициент прироста производства по основным импортозамещающим продуктам животноводства     float64
# Доля импорта отдельных товаров в их товарных ресурсах, %                                    float64
# Оборот средних организаций по субъектам РФ, млрд. руб.                                      float64
# Удельный вес потребительских товаров в общем объеме импорта РФ, %                           float64
# Индекс промышленного производства, в%                                                       float64
# dtype: object

# %%
df28_40.describe()
# Out:
#                Год  \
# count    11.000000
# mean   2016.000000
# std       3.316625
# min    2011.000000
# 25%    2013.500000
# 50%    2016.000000
# 75%    2018.500000
# max    2021.000000
#
#        28-40 Импорт продукции химической промышленности, каучука, млн. долл. США  \
# count                                           11.00000
# mean                                         40466.41130
# std                                           5796.62586
# min                                          30847.30000
# 25%                                          37933.01900
# 50%                                          42057.80000
# 75%                                          43864.30380
# max                                          49357.18640
#
#        Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  \
# count                                          11.000000
# mean                                            0.069159
# ...

# %% [markdown]
# ### Датасет: Импорт текстиля, текстильных изделий и обуви, млн. долл. США

# %%
df50_67.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Год                                                                                       11 non-null     int64
#  1   50-67 Импорт текстиля, текстильных изделий и обуви, млн. долл. США                        11 non-null     float64
#  2   Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  11 non-null     float64
#  3   Коэфициент прироста производства по основным импортозамещающим продуктам животноводства   11 non-null     float64
#  4   Доля импорта отдельных товаров в их товарных ресурсах, %                                  11 non-null     float64
# ...

# %%
df50_67.dtypes
# Out:
# Год                                                                                           int64
# 50-67 Импорт текстиля, текстильных изделий и обуви, млн. долл. США                          float64
# Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам    float64
# Коэфициент прироста производства по основным импортозамещающим продуктам животноводства     float64
# Доля импорта отдельных товаров в их товарных ресурсах, %                                    float64
# Оборот средних организаций по субъектам РФ, млрд. руб.                                      float64
# Удельный вес потребительских товаров в общем объеме импорта РФ, %                           float64
# Индекс промышленного производства, в%                                                       float64
# dtype: object

# %%
df50_67.describe()
# Out:
#                Год  \
# count    11.000000
# mean   2016.000000
# std       3.316625
# min    2011.000000
# 25%    2013.500000
# 50%    2016.000000
# 75%    2018.500000
# max    2021.000000
#
#        50-67 Импорт текстиля, текстильных изделий и обуви, млн. долл. США  \
# count                                          11.000000
# mean                                        13097.410600
# std                                          2113.992625
# min                                          9456.570600
# 25%                                         12253.576500
# 50%                                         13142.040000
# 75%                                         14581.596550
# max                                         16027.379600
#
#        Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  \
# count                                          11.000000
# mean                                            0.069159
# ...

# %% [markdown]
# ### Датасет: Импорт металлов и изделий из них, млн. долл. США

# %%
df72_83.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Год                                                                                       11 non-null     int64
#  1   72-83 Импорт металлов и изделий из них, млн. долл. США                                    11 non-null     float64
#  2   Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  11 non-null     float64
#  3   Коэфициент прироста производства по основным импортозамещающим продуктам животноводства   11 non-null     float64
#  4   Доля импорта отдельных товаров в их товарных ресурсах, %                                  11 non-null     float64
# ...

# %%
df72_83.dtypes
# Out:
# Год                                                                                           int64
# 72-83 Импорт металлов и изделий из них, млн. долл. США                                      float64
# Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам    float64
# Коэфициент прироста производства по основным импортозамещающим продуктам животноводства     float64
# Доля импорта отдельных товаров в их товарных ресурсах, %                                    float64
# Оборот средних организаций по субъектам РФ, млрд. руб.                                      float64
# Удельный вес потребительских товаров в общем объеме импорта РФ, %                           float64
# Индекс промышленного производства, в%                                                       float64
# dtype: object

# %%
df72_83.describe()
# Out:
#                Год  72-83 Импорт металлов и изделий из них, млн. долл. США  \
# count    11.000000                                          11.000000
# mean   2016.000000                                       13035.260891
# std       3.316625                                        2459.843596
# min    2011.000000                                        8713.270300
# 25%    2013.500000                                       11960.995250
# 50%    2016.000000                                       13362.979200
# 75%    2018.500000                                       15170.648300
# max    2021.000000                                       15642.397400
#
#        Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам  \
# count                                          11.000000
# mean                                            0.069159
# std                                             0.043734
# min                                             0.012779
# ...

# %%
import matplotlib.dates as mdates

# %%
def data_plot(df):
    df_plot = df.copy()
 
    ncols = 2
    nrows = int(round(df_plot.shape[1] / ncols, 0))
 
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols,
                           sharex=True, figsize=(14, 7))
    for i, ax in enumerate(fig.axes):
        sns.lineplot(data=df_plot.iloc[:, i-1], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    fig.tight_layout()
    plt.show()
 
data_plot(df)
# Out:
# C:\Users\valentina.filippenko\AppData\Local\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\valentina.filippenko\AppData\Local\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\valentina.filippenko\AppData\Local\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Матрицы корреляций

# %% [markdown]
# ### Датасет: Импорт России важнейших товаров, млн долл США

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                                                          Год  \
# Год                                                 1.000000
# Импорт России важнейших товаров, млн долл США      -0.533511
# Средний коэфициент прироста производства по осн...  0.111022
# Коэфициент прироста производства по основным им... -0.813563
# Доля импорта отдельных товаров в их товарных ре... -0.100182
# Оборот средних организаций по субъектам РФ, млр...  0.919694
# Удельный вес потребительских товаров в общем об... -0.881483
# Индекс промышленного производства, в%               0.973144
#
#                                                     Импорт России важнейших товаров, млн долл США  \
# Год                                                                                     -0.533511
# Импорт России важнейших товаров, млн долл США                                            1.000000
# Средний коэфициент прироста производства по осн...                                       0.182651
# ...

# %% [markdown]
# ### Датасет: Импорт продукции химической промышленности, каучука, млн. долл. США

# %%
plt.figure(figsize=(10,5))
c= df28_40.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                                                          Год  \
# Год                                                 1.000000
# 28-40 Импорт продукции химической промышленност...  0.054666
# Средний коэфициент прироста производства по осн...  0.111022
# Коэфициент прироста производства по основным им... -0.813563
# Доля импорта отдельных товаров в их товарных ре... -0.100182
# Оборот средних организаций по субъектам РФ, млр...  0.919694
# Удельный вес потребительских товаров в общем об... -0.881483
# Индекс промышленного производства, в%               0.973144
#
#                                                     28-40 Импорт продукции химической промышленности, каучука, млн. долл. США  \
# Год                                                                                          0.054666
# 28-40 Импорт продукции химической промышленност...                                           1.000000
# ...

# %% [markdown]
# ### Датасет: Импорт текстиля, текстильных изделий и обуви, млн. долл. США

# %%
plt.figure(figsize=(10,5))
c= df50_67.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                                                          Год  \
# Год                                                 1.000000
# 50-67 Импорт текстиля, текстильных изделий и об... -0.262842
# Средний коэфициент прироста производства по осн...  0.111022
# Коэфициент прироста производства по основным им... -0.813563
# Доля импорта отдельных товаров в их товарных ре... -0.100182
# Оборот средних организаций по субъектам РФ, млр...  0.919694
# Удельный вес потребительских товаров в общем об... -0.881483
# Индекс промышленного производства, в%               0.973144
#
#                                                     50-67 Импорт текстиля, текстильных изделий и обуви, млн. долл. США  \
# Год                                                                                         -0.262842
# 50-67 Импорт текстиля, текстильных изделий и об...                                           1.000000
# ...

# %% [markdown]
# ### Датасет: Импорт металлов и изделий из них, млн. долл. США

# %%
plt.figure(figsize=(10,5))
c= df72_83.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                                                          Год  \
# Год                                                 1.000000
# 72-83 Импорт металлов и изделий из них, млн. до... -0.262364
# Средний коэфициент прироста производства по осн...  0.111022
# Коэфициент прироста производства по основным им... -0.813563
# Доля импорта отдельных товаров в их товарных ре... -0.100182
# Оборот средних организаций по субъектам РФ, млр...  0.919694
# Удельный вес потребительских товаров в общем об... -0.881483
# Индекс промышленного производства, в%               0.973144
#
#                                                     72-83 Импорт металлов и изделий из них, млн. долл. США  \
# Год                                                                                         -0.262364
# 72-83 Импорт металлов и изделий из них, млн. до...                                           1.000000
# Средний коэфициент прироста производства по осн...                                           0.247709
# ...

# %% [markdown]
# ## Проверка на выборосы в данных

# %%
fig, ax = plt.subplots(figsize=(20, 20))

df.boxplot()
# set plot title and axis labels
plt.title('Boxplots для характиризующих переменных')
plt.ylabel('Значение')

# display the plot
plt.show()

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Год                                                                                            5.000000
# Импорт России важнейших товаров, млн долл США                                               4323.273077
# Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам       0.049363
# Коэфициент прироста производства по основным импортозамещающим продуктам животноводства        0.019970
# Доля импорта отдельных товаров в их товарных ресурсах, %                                      28.980769
# Оборот средних организаций по субъектам РФ, млрд. руб.                                      2285.850000
# Удельный вес потребительских товаров в общем объеме импорта РФ, %                              1.866667
# Индекс промышленного производства, в%                                                         12.550000
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ## Проверка коррелиции между переменными

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам'], 
           df['Коэфициент прироста производства по основным импортозамещающим продуктам животноводства'])
ax.set_xlabel('Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам')

ax.set_ylabel('Коэфициент прироста производства по основным импортозамещающим продуктам животноводства')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Доля импорта отдельных товаров в их товарных ресурсах, %'], 
           df['Оборот средних организаций по субъектам РФ, млрд. руб.'])
ax.set_xlabel('Доля импорта отдельных товаров в их товарных ресурсах, %')

ax.set_ylabel('Оборот средних организаций по субъектам РФ, млрд. руб.')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Удельный вес потребительских товаров в общем объеме импорта РФ, %'], 
           df['Индекс промышленного производства, в%'])
ax.set_xlabel('Удельный вес потребительских товаров в общем объеме импорта РФ, %')

ax.set_ylabel('Индекс промышленного производства, в%')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Доля импорта отдельных товаров в их товарных ресурсах, %'], 
           df['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам'])
ax.set_xlabel('Доля импорта отдельных товаров в их товарных ресурсах, %')

ax.set_ylabel('Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Индекс промышленного производства, в%'], 
           df['Коэфициент прироста производства по основным импортозамещающим продуктам животноводства'])
ax.set_xlabel('Индекс промышленного производства, в%')

ax.set_ylabel('Коэфициент прироста производства по основным импортозамещающим продуктам животноводства')
plt.show()

# %% [markdown]
# ## Выбор признаков для итоговых датасетов

# %%
df = df.drop(['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам',
              'Коэфициент прироста производства по основным импортозамещающим продуктам животноводства',
             'Удельный вес потребительских товаров в общем объеме импорта РФ, %'], axis = 1)

# %%
df.head(3)
# Out:
#     Год  Импорт России важнейших товаров, млн долл США  \
# 0  2011                                       222845.7
# 1  2012                                       240534.0
# 2  2013                                       236397.7
#
#    Оборот средних организаций по субъектам РФ, млрд. руб.  \
# 0                                             3925.6
# 1                                             4136.1
# 2                                             4295.9
#
#    Индекс промышленного производства, в%  \
# 0                                  105.0
# 1                                  109.0
# 2                                  109.0
#
#    Средняя доля импорта отдельных товаров в их товарных ресурсах, %
# 0                                          23.414286
# 1                                          24.328571
# 2                                          24.221429

# %%
df.to_excel('df_import.xlsx', index = False)

# %%
df28_40 = df28_40.drop(['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам',
                        'Коэфициент прироста производства по основным импортозамещающим продуктам животноводства',
                        'Удельный вес потребительских товаров в общем объеме импорта РФ, %'], axis = 1)
df28_40.head(7)
# Out:
#     Год  \
# 0  2011
# 1  2012
# 2  2013
# 3  2014
# 4  2015
# 5  2016
# 6  2017
#
#    28-40 Импорт продукции химической промышленности, каучука, млн. долл. США  \
# 0                                         42057.8000
# 1                                         43896.3000
# 2                                         45923.8000
# 3                                         42629.7000
# 4                                         30847.3000
# 5                                         31033.4453
# 6                                         36952.7959
#
#    Доля импорта отдельных товаров в их товарных ресурсах, %  \
# 0                                          50.069231
# 1                                          24.084615
# 2                                          11.907692
# 3                                          13.738462
# 4                                       45474.000000
# 5                                          29.061538
# ...

# %%
df28_40.to_excel('df28_40_import.xlsx', index = False)

# %%
df50_67 = df50_67.drop(['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам',
                        'Коэфициент прироста производства по основным импортозамещающим продуктам животноводства',
                        'Удельный вес потребительских товаров в общем объеме импорта РФ, %'], axis = 1)
df50_67.head(7)
# Out:
#     Год  50-67 Импорт текстиля, текстильных изделий и обуви, млн. долл. США  \
# 0  2011                                         14499.2698
# 1  2012                                         14763.6323
# 2  2013                                         16027.3796
# 3  2014                                         14663.9233
# 4  2015                                          9651.1212
# 5  2016                                          9456.5706
# 6  2017                                         11810.7103
#
#    Доля импорта отдельных товаров в их товарных ресурсах, %  \
# 0                                          50.069231
# 1                                          24.084615
# 2                                          11.907692
# 3                                          13.738462
# 4                                       45474.000000
# 5                                          29.061538
# 6                                          36.853846
#
# ...

# %%
df50_67.to_excel('df50_67_import.xlsx', index = False)

# %%
df72_83 = df72_83.drop(['Средний коэфициент прироста производства по основным импортозамещающим пищевым продуктам',
                        'Коэфициент прироста производства по основным импортозамещающим продуктам животноводства',
                        'Удельный вес потребительских товаров в общем объеме импорта РФ, %'], axis = 1)
df72_83.head(7)
# Out:
#     Год  72-83 Импорт металлов и изделий из них, млн. долл. США  \
# 0  2011                                         15354.8816
# 1  2012                                         15305.4663
# 2  2013                                         15642.3974
# 3  2014                                         14429.8614
# 4  2015                                          9105.8058
# 5  2016                                          8713.2703
# 6  2017                                         11500.8314
#
#    Доля импорта отдельных товаров в их товарных ресурсах, %  \
# 0                                          50.069231
# 1                                          24.084615
# 2                                          11.907692
# 3                                          13.738462
# 4                                       45474.000000
# 5                                          29.061538
# 6                                          36.853846
#
# ...

# %%
df72_83.to_excel('df72_83_import.xlsx', index = False)
